# %% [markdown]
# # Leveraging Gen AI for SAT Prep - Semantic Similarity
#
# This notebook showcases how I used semantic similarity to find the best suited word for a given genre to reduce hallucination.
#
# Semantic similarity is based on this paper: https://arxiv.org/pdf/2108.06130

# %%
# %pip install llama-index-embeddings-huggingface
# %pip install llama-index-embeddings-instructor
# %pip install llama-index
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting llama-index-embeddings-huggingface
#   Downloading llama_index_embeddings_huggingface-0.5.2-py3-none-any.whl (8.9 kB)
# Collecting sentence-transformers>=2.6.1
#   Downloading sentence_transformers-3.4.1-py3-none-any.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.9/275.9 KB 6.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-embeddings-huggingface) (0.12.25)
# Requirement already satisfied: huggingface-hub[inference]>=0.19.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-embeddings-huggingface) (0.29.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/lib/python3/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.3.1)
# Requirement already satisfied: requests in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.67.1)
# Requirement already satisfied: packaging>=20.9 in /usr/lib/python3/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.12.2)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.6.0)
# Requirement already satisfied: aiohttp in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.11.14)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (9.0.0)
# Requirement already satisfied: nltk>3.8.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.9.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.0.39)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.18)
# Requirement already satisfied: networkx>=3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.4.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/lib/python3/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (9.0.1)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: pydantic>=2.8.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.10.6)
# Requirement already satisfied: dataclasses-json in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: httpx in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.28.1)
# Requirement already satisfied: wrapt in /usr/lib/python3/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.13.3)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.21.5)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.49.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/lib/python3/dist-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.6.0)
# Requirement already satisfied: scikit-learn in /usr/lib/python3/dist-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.23.2)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.8.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (21.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.18.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (5.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.6.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2024.11.6)
# Requirement already satisfied: joblib in /usr/lib/python3/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.17.0)
# Requirement already satisfied: click in /home/ubuntu/.local/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (8.1.8)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.26.5)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.1.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.5.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.21.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (3.26.1)
# Requirement already satisfied: anyio in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ubuntu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-huggingface) (1.2.2)
# Installing collected packages: sentence-transformers, llama-index-embeddings-huggingface
# Successfully installed llama-index-embeddings-huggingface-0.5.2 sentence-transformers-3.4.1
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting llama-index-embeddings-instructor
#   Downloading llama_index_embeddings_instructor-0.3.0-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: torch<3.0.0,>=2.1.2 in /usr/lib/python3/dist-packages (from llama-index-embeddings-instructor) (2.6.0)
# Collecting sentence-transformers<3.0.0,>=2.2.2
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 KB 4.0 MB/s eta 0:00:00a 0:00:01
# Collecting instructorembedding<2.0.0,>=1.0.1
#   Downloading InstructorEmbedding-1.0.1-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-embeddings-instructor) (0.12.25)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (6.0.2)
# Requirement already satisfied: pydantic>=2.8.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.10.6)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.2.18)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.21.5)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.9.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.11.14)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (9.0.0)
# Requirement already satisfied: wrapt in /usr/lib/python3/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.13.3)
# Requirement already satisfied: networkx>=3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.4.2)
# Requirement already satisfied: httpx in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.28.1)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.9.0)
# Requirement already satisfied: dataclasses-json in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.6.7)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.6.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (4.12.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (4.67.1)
# Requirement already satisfied: pillow>=9.0.0 in /usr/lib/python3/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (9.0.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/lib/python3/dist-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2024.3.1)
# Requirement already satisfied: nltk>3.8.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.9.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.2.0)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.0.8)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.0.39)
# Requirement already satisfied: requests>=2.31.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.32.3)
# Requirement already satisfied: scikit-learn in /usr/lib/python3/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (0.23.2)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (4.49.0)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (1.8.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (0.29.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (21.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.6.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.18.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.3.2)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (6.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.5.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (5.0.1)
# Requirement already satisfied: packaging>=20.9 in /usr/lib/python3/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (21.3)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (3.6.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2024.11.6)
# Requirement already satisfied: joblib in /usr/lib/python3/dist-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.17.0)
# Requirement already satisfied: click in /home/ubuntu/.local/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (8.1.8)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.7.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.1.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (0.5.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0.0,>=2.2.2->llama-index-embeddings-instructor) (0.21.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (3.26.1)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.0.7)
# Requirement already satisfied: anyio in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (4.9.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ubuntu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-instructor) (1.2.2)
# Installing collected packages: instructorembedding, sentence-transformers, llama-index-embeddings-instructor
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.4.1
#     Uninstalling sentence-transformers-3.4.1:
#       Successfully uninstalled sentence-transformers-3.4.1
# Successfully installed instructorembedding-1.0.1 llama-index-embeddings-instructor-0.3.0 sentence-transformers-2.7.0
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: llama-index in /home/ubuntu/.local/lib/python3.10/site-packages (0.12.25)
# Requirement already satisfied: llama-index-agent-openai<0.5.0,>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (0.4.6)
# Requirement already satisfied: llama-index-question-gen-openai<0.4.0,>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (0.6.9)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (0.3.25)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.25 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (0.12.25)
# Requirement already satisfied: llama-index-program-openai<0.4.0,>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-embeddings-openai<0.4.0,>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-cli<0.5.0,>=0.4.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (0.4.1)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5.0,>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (0.4.3)
# Requirement already satisfied: llama-index-readers-file<0.5.0,>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index) (0.4.6)
# Requirement already satisfied: openai>=1.14.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.66.5)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (2.0.39)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (1.6.0)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (1.2.18)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (0.9.0)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (1.0.8)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (9.0.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (3.11.14)
# Requirement already satisfied: pydantic>=2.8.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (2.10.6)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (4.12.2)
# Requirement already satisfied: requests>=2.31.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (2.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/lib/python3/dist-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (2024.3.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (4.67.1)
# Requirement already satisfied: dataclasses-json in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (0.6.7)
# Requirement already satisfied: networkx>=3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (3.4.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/lib/python3/dist-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (9.0.1)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (1.21.5)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /usr/lib/python3/dist-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (1.13.3)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (1.2.0)
# Requirement already satisfied: httpx in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.25->llama-index) (0.28.1)
# Requirement already satisfied: llama-cloud<0.2.0,>=0.1.13 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.15)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: pandas in /usr/lib/python3/dist-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (1.3.5)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (4.13.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (5.4.0)
# Requirement already satisfied: llama-parse>=0.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.4.post1)
# Requirement already satisfied: regex>=2021.8.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: joblib in /usr/lib/python3/dist-packages (from nltk>3.8.1->llama-index) (0.17.0)
# Requirement already satisfied: click in /home/ubuntu/.local/lib/python3.10/site-packages (from nltk>3.8.1->llama-index) (8.1.8)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.25->llama-index) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.25->llama-index) (0.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.25->llama-index) (21.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.25->llama-index) (1.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.25->llama-index) (1.18.3)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.25->llama-index) (5.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.25->llama-index) (2.6.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.25->llama-index) (1.5.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/lib/python3/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5.0,>=0.4.0->llama-index) (2.3.1)
# Requirement already satisfied: certifi>=2024.7.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-cloud<0.2.0,>=0.1.13->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2025.1.31)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx->llama-index-core<0.13.0,>=0.12.25->llama-index) (3.3)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.25->llama-index) (1.0.7)
# Requirement already satisfied: anyio in /home/ubuntu/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.25->llama-index) (4.9.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ubuntu/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.25->llama-index) (0.14.0)
# Requirement already satisfied: llama-cloud-services>=0.6.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.6)
# Requirement already satisfied: sniffio in /home/ubuntu/.local/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (0.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.5.0,>=0.4.0->llama-index) (1.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.25->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.25->llama-index) (2.27.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.25->llama-index) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.25->llama-index) (3.4.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.25->llama-index) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.25->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.25->llama-index) (3.26.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.25->llama-index) (1.2.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from llama-cloud-services>=0.6.4->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.0.1)
# Requirement already satisfied: packaging>=17.0 in /usr/lib/python3/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.25->llama-index) (21.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Using BAAI/bge-large-en-v1.5 for evaluating Semantic Similarity

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
cache_dir="/home/ubuntu/Pragyan/model_cache"
embed_model = HuggingFaceEmbedding( model_name="BAAI/bge-large-en-v1.5", trust_remote_code=True)
# Out:
# 2025-03-19 03:47:31.284242: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742356051.314005    2951 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742356051.323617    2951 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# Similarity score ranges from 0 - 1. 0 means no similarity and 1 means high semantic similarity. Setting the threshold to 0.5 so that we have at least one word with similarity of 0.5 of higher.

# %%
from llama_index.core.evaluation import SemanticSimilarityEvaluator
from llama_index.core.embeddings import resolve_embed_model

evaluator = SemanticSimilarityEvaluator(
    embed_model=embed_model,
    similarity_threshold=0.5,
)

# %%
from transformers import LlamaForCausalLM, AutoModelForCausalLM, AutoTokenizer
import torch
from huggingface_hub import login

model_id="meta-llama/Meta-Llama-3-8B-Instruct"
access_token="<your HF Token>"
login(token = access_token)

device = "cuda:0" if torch.cuda.is_available() else "cpu"
print(device)

cache_dir="/home/ubuntu/Pragyan/model_cache"

model=AutoModelForCausalLM.from_pretrained(model_id, token=access_token, cache_dir=cache_dir).to(device)
tokenizer= AutoTokenizer.from_pretrained(model_id, token=access_token, cache_dir=cache_dir)
# Out:
# cuda:0
# Loading checkpoint shards: 100%|██████████| 4/4 [00:11<00:00,  2.83s/it]

# %%
from transformers import GenerationConfig
generation_config = GenerationConfig(
        # number of tokens to generate
        max_new_tokens=20,  
        # only choose from the top k most likely words
        top_k=20,  
        # Whether or not to use sampling ; use greedy decoding otherwise.
        do_sample=True,
        # parameter that controls the randomness or creativity of the generated text
        temperature=0.001, 
        # sets the pad tokens to whatever it is in the tokenizer
        pad_token_id=tokenizer.eos_token_id, 
        # output unnormalized outputs
        output_logits=True,
        # output the probabilities
        output_scores=True,   
        # passes hidden state along with output
        output_hidden_states=True,
        #returns output as a dict
        return_dict_in_generate=True,
        # reduce repetition
        #repetition_penalty=1.5
    )

print(generation_config)
# Out:
# GenerationConfig {
#   "do_sample": true,
#   "max_new_tokens": 20,
#   "output_hidden_states": true,
#   "output_logits": true,
#   "output_scores": true,
#   "pad_token_id": 128009,
#   "return_dict_in_generate": true,
#   "temperature": 0.001,
#   "top_k": 20
# }

# %%
# function for running inference against the model
def run_inference(prompt):
    inputs = tokenizer([prompt], return_tensors="pt").to(device)
    outputs=model.generate(**inputs, generation_config=generation_config)
    transition_scores = model.compute_transition_scores(outputs.sequences, outputs.scores, normalize_logits=True)  
    input_length = 1 if model.config.is_encoder_decoder else inputs.input_ids.shape[1]
    complete_text=''
    for t in outputs.sequences:
        complete_text += tokenizer.decode(t)
        
    generated_tokens = outputs.sequences[:,input_length:]
    generated_text = ''
    for t in generated_tokens:
        generated_text += tokenizer.decode(t)
        
    return [generated_text, generated_tokens, transition_scores, complete_text]

# %% [markdown]
# ### Word dataset with definition

# %%
import pandas as pd
import random
import time
import random
from random import randrange
vocab_df = pd.read_csv('sat_vocab.csv')
print("Sample word: {} ".format(vocab_df.head(5)))
# Out:
# Sample word:          word
# 0       Abate
# 1  Aberration
# 2       Abhor
# 3      Abject
# 4      Abjure

# %% [markdown]
# ### Genre dataset

# %%
genre_df = pd.read_csv('sat_genre.csv')
print("Sample genre: {} ".format(genre_df.head(5)))
# Out:
# Sample genre:                          genre
# 0    Emergence of Homo sapiens
# 1  Use of fire by early humans
# 2   Development of stone tools
# 3      Agricultural Revolution
# 4     Establishment of Jericho

# %%
def find_antonym(word):
    prompt = "Antonym for the word abate is intensify. What is the antonym of the word {} is? It should be an uncommon word.".format(word);
    output = run_inference(prompt)
    antonym = output[0].split('.')[0].lower().strip().split(" ")[-1]
    return antonym

def find_word_meaning(word):
    prompt = "Definition of the word {} is".format(word);
    output = run_inference(prompt)
    meaning = output[0].split('.')[0].lower().strip()
    if meaning.startswith(":"):
        meaning = meaning.split(":")[1]
    return meaning

# %%
print(find_antonym('abate'))
print(find_antonym('castigate'))
# Out:
# augment
# extol

# %%
print(find_word_meaning('augment'))
print(find_word_meaning('extol'))
# Out:
#  to increase or add to something, especially to make it more effective or valuable
#  to praise highly; to glorify; to commend

# %% [markdown]
# Following code selects a random genre, selects 10 random words, and checks the semantic similarity for each combination. Finally, comes up with combintations that has the highest score and the score should be .5 or above.

# %%
output_df = DataFrame(columns=['genre', 'word', 'similarity_score', 'answer_choices', 'answer_choices_with_score'])
test_cases_count=100
word_count=20
invalid_choice_count=2
counter = 0
while True:
    words=[]
    genre = (genre_df['genre'][randrange(genre_df.shape[0])]).lower()
    for i in range (word_count):
        key = randrange(vocab_df.shape[0])
        words.append((vocab_df['word'][randrange(vocab_df.shape[0])]).lower())       
    
    highest_score=0
    similarity_scores={}
    selected_word=''
    passing_count=0
    for i in range (len(words)):
        result = await evaluator.aevaluate(
            response=genre,
            reference=words[i],
        )
        similarity_scores.update({result.score:words[i]})
        if (result.passing):
            passing_count += 1
        # print("{},{}".format(words[i],result.score))
    
    # we need atleast one match with greater than 50%
    if passing_count == 0:
        continue
        
    # sort the ditionary so that we can pick the word that has highest similarity and pick 
    # the bottom 3 for invalid choices
    scores = list(similarity_scores.keys())
    scores.sort()
    sorted_scores = {i: similarity_scores[i] for i in scores}

    # word with highest similarity
    selected_word = sorted_scores[scores[len(scores) - 1]]

    answer_choices=[]
    answer_choices.append(selected_word)

    answer_choices_with_score={}
    # add invalid choices
    for k in range(invalid_choice_count):
        invalid_choice = sorted_scores[scores[k]]
        answer_choices.append(invalid_choice)
        answer_choices_with_score[invalid_choice] = scores[k]
    
    # add an antonym
    antonym = find_antonym(selected_word)
    answer_choices.append(antonym)
    random.shuffle(answer_choices)
    answer_choices_with_score[antonym] = 'antonym'
    answer_choices_with_score[selected_word] = 'correct answer'
    
    # capture the word definition
    answer_choices_with_def={}
    for i in range (len(answer_choices)):
        choice = answer_choices[i]
        answer_choices_with_def[choice] = find_word_meaning(choice)

    
    for i in range (len(answer_choices)):
        choice = answer_choices[i]
        answer_choices_with_def[choice] = find_word_meaning(choice)

    # store in the dataframe
    output_df = output_df.append({'genre':genre,'word': selected_word, 
        'similarity_score':scores[len(scores) - 1],'answer_choices':answer_choices_with_def,
        'answer_choices_with_score':answer_choices_with_score}, 
        ignore_index=True)
    print("{} - Genre: {}; Word {}; Score: {} ".format(counter, genre, selected_word, scores[len(scores) - 1]))

    counter += 1
    
    # break if test cases count has been reached
    if counter >= test_cases_count:
        break
# Out:
# 0 - Genre: korean war; Word impasse; Score: 0.5604859574272113
# 1 - Genre: invention of the printing press; Word catalyst; Score: 0.531469707132798
# 2 - Genre: 9/11 terrorist attacks; Word resilient; Score: 0.5455340221089306
# 3 - Genre: unification of germany; Word laud; Score: 0.5351095440083806
# 4 - Genre: futurist conceptual designs; Word whimsical; Score: 0.5253310403956992
# 5 - Genre: the history of curling; Word engross; Score: 0.5197745729355853
# 6 - Genre: deconstructivist museums; Word enrapture; Score: 0.5289703605621967
# 7 - Genre: formation of the grand canyon; Word exigent; Score: 0.5432685705065593
# 8 - Genre: advent of quantum computing; Word quandary; Score: 0.5411630610170756
# 9 - Genre: the history of ice hockey; Word anachronistic; Score: 0.5212942984138771
# 10 - Genre: development of modern ocean currents; Word ubiquitous; Score: 0.5260845268153582
# 11 - Genre: persian wars; Word temptation; Score: 0.5271377074430801
# 12 - Genre: african tribal huts; Word dilapidated; Score: 0.5390925439576624
# 13 - Genre: emergence of early bats; Word gregarious; Score: 0.5293141740022262
# 14 - Genre: formation of the mediterranean sea; Word copious; Score: 0.5270653945104948
# 15 - Genre: first tectonic plate collisions forming mountains; Word anomaly; Score: 0.5043063976849649
# 16 - Genre: scandinavian minimalist homes; Word austere; Score: 0.5899778545077974
# 17 - Genre: thirty years' war; Word garrulous; Score: 0.5592389544174268
# 18 - Genre: formation of the soviet union; Word clandestine; Score: 0.5496862468166314
# 19 - Genre: fall of the western roman empire; Word subjugate; Score: 0.5320406102526298
# 20 - Genre: futurist conceptual designs; Word feign; Score: 0.5563361249503648
# 21 - Genre: byzantine domes; Word virtuous; Score: 0.5110974875297353
# 22 - Genre: cooling of earth's crust; Word ponder; Score: 0.5695327739845023
# 23 - Genre: advent of quantum computing; Word quiescent; Score: 0.5460415689306333
# 24 - Genre: the history of speed skating; Word camaraderie; Score: 0.5259814354216747
# 25 - Genre: founding of rome; Word inculpate; Score: 0.5325785561465423
# 26 - Genre: fall of the western roman empire; Word bureaucracy; Score: 0.5176460088694201
# 27 - Genre: formation of the grand canyon; Word opaque; Score: 0.5243823976486192
# 28 - Genre: development of earth’s modern ecosystems; Word conducive; Score: 0.5318865951096436
# 29 - Genre: extinction of early jawless fish; Word atrophy; Score: 0.5409855898860378
# 30 - Genre: evolution of early crocodilians; Word aggressive; Score: 0.5113580895455744
# 31 - Genre: founding of the roman empire; Word despotism; Score: 0.5693061854367962
# 32 - Genre: founding of the ottoman empire; Word ascendancy; Score: 0.5190938252291476
# 33 - Genre: industrial revolution; Word atrophy; Score: 0.5627420811124808
# 34 - Genre: extinction of early jawless fish; Word cataclysm; Score: 0.5502088024426798
# 35 - Genre: emergence of dinosaurs; Word imposing; Score: 0.5836381709423405
# 36 - Genre: appearance of early elephants and proboscideans; Word fortuitous; Score: 0.5005073692276946
# 37 - Genre: emergence of eukaryotic cells; Word anomaly; Score: 0.5673273047971858
# 38 - Genre: deconstructivist museums; Word crass; Score: 0.5019436578661738
# 39 - Genre: emergence of cephalopods as predators; Word despotism; Score: 0.5310364590310198
# 40 - Genre: colonial american homes; Word zestful; Score: 0.5073825976817833
# 41 - Genre: development of the phoenician alphabet; Word quixotic; Score: 0.572406532957852
# 42 - Genre: invention of the telephone; Word expound; Score: 0.550185206349547
# 43 - Genre: dissolution of the soviet union; Word volatile; Score: 0.5543743174051919
# 44 - Genre: first successful organ transplants; Word ingenious; Score: 0.523886901883254
# 45 - Genre: founding of the roman empire; Word foment; Score: 0.5658286456281257
# 46 - Genre: indigenous longhouses; Word grandiose; Score: 0.5257762570650764
# 47 - Genre: formation of earth's current climate zones; Word nurture; Score: 0.5148884880812941
# 48 - Genre: widespread volcanic activity creating basalt plateaus; Word incessant; Score: 0.5498263927148954
# 49 - Genre: establishment of jericho; Word solace; Score: 0.519026991019062
# 50 - Genre: formation of large desert regions in ancient pangaea; Word ignoble; Score: 0.5041728593974606
# 51 - Genre: evolution of saber-toothed predators; Word malevolent; Score: 0.5331022996159008
# 52 - Genre: indigenous longhouses; Word capacious; Score: 0.514492817200894
# 53 - Genre: human genome project completion; Word epitome; Score: 0.5442910371309468
# 54 - Genre: global population surpasses 8 billion; Word engross; Score: 0.5269566123820187
# 55 - Genre: scientific revolution; Word subversive; Score: 0.5979745986216942
# 56 - Genre: formation of coal deposits from ancient forests; Word viscous; Score: 0.5109931750970855
# 57 - Genre: volcanic eruptions shaping global climate; Word decimate; Score: 0.5037777282926464
# 58 - Genre: establishment of the international space station; Word embrace; Score: 0.5259539801164348
# 59 - Genre: invention of the smartphone; Word aberrant; Score: 0.5250626799104227
# 60 - Genre: napoleonic wars; Word avarice; Score: 0.5540016143144445
# 61 - Genre: the history of handball; Word anachronism; Score: 0.5159411289514341
# 62 - Genre: buddhist stupas; Word auspicious; Score: 0.5306246123470264
# 63 - Genre: first successful organ transplants; Word benevolent; Score: 0.5385099654685793
# 64 - Genre: discovery of dna structure; Word prolific; Score: 0.5633095841476483
# 65 - Genre: english civil war; Word laud; Score: 0.540896224114705
# 66 - Genre: creation of the amazon rainforest; Word expound; Score: 0.5167683859347632
# 67 - Genre: sustainable bamboo houses; Word resilient; Score: 0.5352261372795665
# 68 - Genre: french revolution; Word harangue; Score: 0.5685189180030498
# 69 - Genre: protestant reformation; Word dogmatic; Score: 0.6061062845068763
# 70 - Genre: formation of the grand canyon; Word conjecture; Score: 0.5322215214531442
# 71 - Genre: invention of the telephone; Word anachronism; Score: 0.5413289499608233
# 72 - Genre: appearance of the first fish; Word abundant; Score: 0.5592566514479127
# 73 - Genre: brutalist structures; Word abject; Score: 0.6124405099737301
# 74 - Genre: formation of the sahara desert; Word anachronism; Score: 0.5570123015929913
# 75 - Genre: neo-gothic universities; Word archaic; Score: 0.5552214649571751
# 76 - Genre: evolution of early shell-forming organisms; Word aversion; Score: 0.5272779022110751
# 77 - Genre: the history of judo; Word anachronism; Score: 0.5293782563417662
# 78 - Genre: founding of the european union; Word laud; Score: 0.5363175266498504
# 79 - Genre: evolution of early primates adapted to arboreal life; Word abundant; Score: 0.513188843703901
# 80 - Genre: julius caesar's assassination; Word infamous; Score: 0.5602497458304839
# 81 - Genre: byzantine domes; Word diverge; Score: 0.505395928341005
# 82 - Genre: formation of the modern atlantic ocean basin; Word envision; Score: 0.5441896128770908
# 83 - Genre: evolution of birds from dinosaurs; Word cryptic; Score: 0.5304116301467485
# 84 - Genre: world war ii; Word contrite; Score: 0.5044957662616972
# 85 - Genre: establishment of the international space station; Word altruism; Score: 0.5481160781362261
# 86 - Genre: establishment of jericho; Word relinquish; Score: 0.5137474079364512
# 87 - Genre: craftsman bungalows; Word holistic; Score: 0.5161598972304525
# 88 - Genre: cooling of earth's crust; Word precipitate; Score: 0.5701619499730441
# 89 - Genre: the history of rowing; Word burgeon; Score: 0.5103261100384783
# 90 - Genre: cryogenian ice age ("snowball earth"); Word rejuvenate; Score: 0.5462111058695656
# 91 - Genre: breakup of rodinia; Word consensus; Score: 0.5541095989439575
# 92 - Genre: development of the ozone layer; Word resilient; Score: 0.5400672193927203
# 93 - Genre: black death in europe; Word awry; Score: 0.5254798442806883
# 94 - Genre: moon landing; Word brazen; Score: 0.5573303640389916
# 95 - Genre: advent of quantum computing; Word prodigy; Score: 0.5380538364449483
# 96 - Genre: breakup of rodinia; Word redundant; Score: 0.5479885775485155
# 97 - Genre: great depression; Word somber; Score: 0.6365884095298419
# 98 - Genre: evolution of cartilaginous fish (sharks and rays); Word craven; Score: 0.5227942204668327
# 99 - Genre: persian wars; Word belligerent; Score: 0.5666410534152297

# %%
# write the dataframe to a csv file
output_df.to_csv('test_eval_word_genre.csv', index=False)
